# %% [markdown]
# <a href="https://colab.research.google.com/github/sba25046/ml-test/blob/main/Linear_Regression_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.DataFrame({
    "Hours Studied": [2, 3, 4, 7, 10],
    "Exam Scores": [50, 55, 65, 70, 75]
})



X = pd.DataFrame(df["Hours Studied"])
y = df["Exam Scores"]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Slope (coefficient):", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Slope (coefficient): [2.96728972]
# Intercept: 47.570093457943926

# %% [markdown]
# ## Model Linear Equation
#
# $y = 6.5\times x + 43.5$

# %%
new_data = pd.DataFrame({
    "Hours Studied": [6, 1.5, 2]
})

model.predict(pd.DataFrame(new_data["Hours Studied"]))
# Out:
# array([65.37383178, 52.02102804, 53.5046729 ])

# %%
6.5*6+43.5
# Out:
# 82.5

# %%
6.5*1.5+43.5
# Out:
# 53.25

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# ## Model Evaluation
#
# We use a train-test split to evaluate the performance of the model.<br>
# We train it on part of the data, and test it on the rest.<br>
# Since we know what the values **should** be, this allows us to calulate the errors (how wrong the model is).

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=72
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R-squared:", r2)
# Out:
# MSE: 35.60422437673125
# R-squared: 0.6439577562326875
